# %% [markdown]
# # Melon 100 차트 스크래핑
# *100곡 노래의 제목,ID를 추출
#
# *Song ID를 상세 페이지를 100번 요청을 해서 상세정보를 추출
#
# *100곡의 노래상세정보를 Json File에 저장한다
#
# *Json File에 정보를 읽어서 Pandas의 DataFrame에 저장해서 표 데이터를 만듬
#
# *표 데이터를 Maria DB에 저장하기

# %%
import requests
from bs4 import BeautifulSoup
import re

url = 'https://www.melon.com/chart/index.htm'
req_header = {
     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36'
}

#요청을 보내기
res = requests.get(url,headers=req_header)
print(type(res))

#응답코드 200(ok)가 정상이면
if res.ok:
    html = res.text
    #response 객체에 포힘된 text를 추출
    html = res.text
    #BeautifulSoup 객체의 역할 - html 문서 파싱
    #텍스트를 추출(parsing)하기 위해서 응답 text와 parser 이름을 전달한다.
    soup = BeautifulSoup(html,'html.parser')
    
    #<div id='tb_list'> div 태그 선택 
    print(len(soup.select('div#tb_list')))#1
    #<div id='tb_list'> 하위에 있는 tr 태그 선택
    print(len(soup.select('div#tb_list tr')))#101
    #<div id='tb_list'> 하위에 있는 tr 하위에 <div class='wrap_song_info'> 태그 선택
    print(len(soup.select('div#tb_list tr div.wrap_song_info')))#200
    #<div id='tb_list'> 하위에 있는 tr 하위에 <div class='wrap_song_info'> 태그 하위에 있는 a 태그 선택
    print(len(soup.select('div#tb_list tr div.wrap_song_info a')))#423
    #<div id='tb_list'> 하위에 있는 tr 하위에 <div class='wrap_song_info'> 태그 하위에 있는 a 태그 
    #a 태그의 href 속성값에 playsong이라는 문자열이 포함된 a 태그를 선택
    print(len(soup.select('div#tb_list tr div.wrap_song_info a[href*="playSong"]')))
    
    atag_list = soup.select('div#tb_list tr div.wrap_song_info a[href*="playSong"]')
    song_list = []
    
    
    for idx,atag in enumerate(atag_list,1): #idx = 인덱스 번호,enumerate=1부터 번호출력
        song_dict = {}
        title= atag.text  #<a>노래제목</a> 노래제목  a tag의 text추출
        href = atag['href']   #<a href=*"playSong">  href속성의 값 추출
        matched = re.search(r'(\d+)\);',href)  #정규표현식 패턴으로 특정 숫자를 검색
        song_id = matched.group(1)  #정규표현식 결과값을 가져오기
        #song 상세페이지 url를 조립
        detail_link = f'https://www.melon.com/song/detail.htm?songid={song_id}'
        #song의 제목과 상세페이지 url을 dict에 저장
        song_dict['title'] = title
        song_dict['link'] = detail_link
        #각각의 song 정보를 저장한 dict를 list에 저장
        song_list.append(song_dict)
        
        #print(matched.group(0),matched.group(1))
        #print(idx,title,detail_link)
        #print(atag)
        
        
else:
    print('Error코드:', res.status_code)


print(len(song_list))
song_list[0:3]
# Out:
# <class 'requests.models.Response'>
# 1
# 101
# 200
# 423
# 100
# 100
# [{'title': "DON'T TOUCH ME",
#   'link': 'https://www.melon.com/song/detail.htm?songid=32978341'},
#  {'title': 'Dynamite',
#   'link': 'https://www.melon.com/song/detail.htm?songid=32872978'},
#  {'title': 'Lovesick Girls',
#   'link': 'https://www.melon.com/song/detail.htm?songid=32961718'}]

# %% [markdown]
# ###100곡 노래의 제목,ID를 추출

# %%
import requests
from bs4 import BeautifulSoup
import re


req_header = {
     'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36'
}

song_detail_list = []
for song in song_list:
    song_detail_dict = {}
    #print(song['title'],song['link'])
    song_url = song['link']
    res = requests.get(song_url,headers=req_header)
    print(res.status_code)
    if res.ok:
        html = res.text
        soup = BeautifulSoup(html,'html.parser')
        #노래 제목
        song_detail_dict['곡명'] = song['title']
        #가수
        song_detail_dict['가수'] = soup.select('a[href*="goArtistDetail" ] span')[0].text
        #앨범
        song_detail_dict['앨범'] = soup.select('div.meta dd')[0].text
        #발매일
        song_detail_dict['발매일'] = soup.select('div.meta dd')[1].text
        #장르
        song_detail_dict['장르'] = soup.select('div.meta dd')[2].text
        #가사        
       # song_detail_dict['가사'] =  soup.select('div#d_video_summary')[0].text
        lyric =  soup.select('div#d_video_summary')[0].text
        regexp = re.compile(r'[\n\r\t]')
        song_detail_dict['가사'] = regexp.sub('',lyric.strip())
        #각각의 Song정보를 담고 있는 dict를 list에 저장
        song_detail_list.append(song_detail_dict)
        
#         print('----')
#         print(song_detail_dict)
        
        #print(soup)
        
print(len(song_detail_list))
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 100

# %% [markdown]
# ###Song 정보를 담고 있는 List를 JSON file로 저장

# %%
import json

with open('data/songs.json','w',encoding='utf8') as file:
    json.dump(song_detail_list,file)

# %% [markdown]
# ###Json File 읽기

# %%
import json

with open('data/songs.json','r',encoding='utf8') as file:
    content = file.read()
    song_json= json.loads(content)
    
print(len(song_json))
print(type(song_json))
# Out:
# 100
# <class 'list'>

# %% [markdown]
# ### Json file을 읽어서 Pandas의 DataFrame객체에 저장

# %%
import pandas as pd

#DataFrame 객체 생성
song_df = pd.DataFrame(columns=['곡명','가수','앨범','발매일','장르','가사'])
#song_df

for song in song_json:
    series_obj = pd.Series(song)
    song_df = song_df.append(series_obj,ignore_index=True)

song_df.head(3)
# Out:
#                곡명         가수                          앨범         발매일  장르  \
# 0  DON'T TOUCH ME      환불원정대              DON'T TOUCH ME  2020.10.10  댄스
# 1        Dynamite      방탄소년단  Dynamite (DayTime Version)  2020.08.24  댄스
# 2  Lovesick Girls  BLACKPINK                   THE ALBUM  2020.10.02  댄스
#
#                                                   가사
# 0  Trouble 이래 다 그래세 보인대 어쩔래난 멋 부리네 더 꾸미네yeah I'm ...
# 1  Cos ah ahI’m in the stars tonightSo watch me b...
# 2  영원한 밤창문 없는 방에 우릴 가둔 loveWhat can we say매번 아파도 ...

# %%
song_df.tail(3)
# Out:
#                            곡명                   가수             앨범         발매일  \
# 97                 To Die For            Sam Smith     To Die For  2020.02.14
# 98  여름 안에서 by 싹쓰리 (Feat. 황광희)  싹쓰리 (유두래곤, 린다G, 비룡)  여름 안에서 by 싹쓰리  2020.07.11
# 99            PLAY (Feat. 창모)                   청하           PLAY  2020.07.06
#
#      장르                                                 가사
# 97  POP  It is if everyone dies aloneDoes that scare yo...
# 98   댄스  언제나 꿈꿔 온 순간이여기 지금 내게 시작되고 있어그렇게 너를 사랑했던내 마음을 넌...
# 99   댄스  너무 위험한 이 느낌은 babyI wonder how you feel아찔 계속된 이...

# %%
song_df.sample()
# Out:
#             곡명         가수          앨범         발매일   장르  \
# 97  To Die For  Sam Smith  To Die For  2020.02.14  POP
#
#                                                    가사
# 97  It is if everyone dies aloneDoes that scare yo...

# %%
print('shape',song_df.shape)
print('columns',song_df.columns)
print('index',song_df.index)
print('index',song_df.values[0:1]) #2차원 배열
# Out:
# shape (100, 6)
# columns Index(['곡명', '가수', '앨범', '발매일', '장르', '가사'], dtype='object')
# index RangeIndex(start=0, stop=100, step=1)
# index [["DON'T TOUCH ME" '환불원정대' "DON'T TOUCH ME" '2020.10.10' '댄스'
#   "Trouble 이래 다 그래세 보인대 어쩔래난 멋 부리네 더 꾸미네yeah I'm a lady 못 말리네 oh불편한 말들이 또 선을 넘어난 또 보란 듯 해내서 보여줘 버려나도 사랑을 원해나도 평화가 편해하지만 모두가 you know자꾸 건드리네 don't touch mebut 내 멋대로 해blah blah blah so whatI don't care yeah yeah내 맘대로 해자꾸 건드리네 don't touch me괜찮아 걱정 마 So good 난 즐거워몇 살을 먹는대도 절대로 난 안 꿀리는 걸따라 하고 싶지 않아wanna be original남의 눈치 보지 않아자꾸 건드리네 don't touch meUhh Tell me who's hotter NadaYou dealing with afour headed monsta어디 와서 싸구려를 팔아참지 않아 you don't want no problems맘대로 맘대로 hey누가 뭐래도 나대로 hey내가 문제라면 답 없지You can look and starebut don't touch me불편한 말들이 또 선을 넘어난 또 보란 듯 해내서 보여줘 버려나도 사랑을 원해나도 평화가 편해하지만 모두가 you know자꾸 건드리네 don't touch mebut 내 멋대로 해blah blah blah so whatI don't care yeah yeah내 맘대로 해자꾸 건드리네 don't touch me괜찮아 걱정 마 So good 난 즐거워몇 살을 먹는대도 절대로 난 안 꿀리는 걸따라 하고 싶지 않아wanna be original남의 눈치 보지 않아자꾸 건드리네 don't touch me때론 눈물이 쏟아지기도 해결국 날 만든 게 눈물이기도 해 익숙해남들 신경 쓰지 마 절대로Never never 누가 뭐래도 멈추지 마자꾸 건드리네 don't touch mebut 내 멋대로 해blah blah blah so whatI don't care yeah yeah내 맘대로 해자꾸 건드리네 don't touch me괜찮아 걱정 마 So good 난 즐거워몇 살을 먹는대도 절대로 난 안 꿀리는 걸따라 하고 싶지 않아wanna be original남의 눈치 보지 않아자꾸 건드리네 don't touch me자꾸 건드리네 don't touch me"]]

# %%
#가수 컬럼의 값을 선택
song_df['가수']
# Out:
# 0                   환불원정대
# 1                   방탄소년단
# 2               BLACKPINK
# 3                      산들
# 4                   Crush
#              ...
# 95          마마무 (Mamamoo)
# 96              유아 (오마이걸)
# 97              Sam Smith
# 98    싹쓰리 (유두래곤, 린다G, 비룡)
# 99                     청하
# Name: 가수, Length: 100, dtype: object

# %%
#가수별로 row counting
song_df['가수'].value_counts().head(10)
# Out:
# 아이유                    5
# BLACKPINK              5
# Crush                  5
# 방탄소년단                  5
# 싹쓰리 (유두래곤, 린다G, 비룡)    3
# 폴킴                     3
# 청하                     2
# 마크툽 (MAKTUB)           2
# 지코 (ZICO)              2
# 오마이걸 (OH MY GIRL)      2
# Name: 가수, dtype: int64

# %%
#장르별 row counting
song_df['장르'].value_counts()
# Out:
# 댄스                 25
# 발라드                22
# POP                13
# 랩/힙합               11
# 발라드, 국내드라마          9
# R&B/Soul            4
# 록/메탈                3
# 랩/힙합, 인디음악          3
# 록/메탈, 국내드라마         2
# 인디음악, 포크/블루스        2
# R&B/Soul, 인디음악      2
# 성인가요                1
# 발라드, 인디음악           1
# 재즈, 애시드/퓨전/팝        1
# R&B/Soul, 국내드라마     1
# Name: 장르, dtype: int64

# %%
#unique 한 장르명 가져오기
song_df['장르'].unique()
# Out:
# array(['댄스', '발라드', 'R&B/Soul', '인디음악, 포크/블루스', 'POP', '랩/힙합', '록/메탈',
#        '발라드, 국내드라마', '랩/힙합, 인디음악', '록/메탈, 국내드라마', 'R&B/Soul, 인디음악',
#        '발라드, 인디음악', '성인가요', 'R&B/Soul, 국내드라마', '재즈, 애시드/퓨전/팝'],
#       dtype=object)

# %%
#방탄소년단의 노래를 모두 선택
song_df['가수']=='방탄소년단'
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: 가수, Length: 100, dtype: bool

# %% [markdown]
# ### 특정행이나 열을 선택
# *loc[] 과 iloc[] 사용
#
# *1)Slicing을 사용해서 구간을 선택 행과열을 선택:
#
# *2)특정행과 열을 선택 []
#
# *3)조건식을 만족하는 행을 선택

# %%
#loc[] - location의 약자
#특정 행이나 특정 열을 선택할 때 사용한다.
#loc[행을 선택 기준,열을 선택 기준]

#인덱스가 0부터 5까지의 행(Slicing)과 모든열을 선택
song_df.loc[0:5,:]
# Out:
#                              곡명         가수                          앨범  \
# 0                DON'T TOUCH ME      환불원정대              DON'T TOUCH ME
# 1                      Dynamite      방탄소년단  Dynamite (DayTime Version)
# 2                Lovesick Girls  BLACKPINK                   THE ALBUM
# 3         취기를 빌려 (취향저격 그녀 X 산들)         산들       취기를 빌려 (취향저격 그녀 X 산들)
# 4                 놓아줘 (with 태연)      Crush                    with HER
# 5  When We Disco (Duet with 선미)        박진영               When We Disco
#
#           발매일        장르                                                 가사
# 0  2020.10.10        댄스  Trouble 이래 다 그래세 보인대 어쩔래난 멋 부리네 더 꾸미네yeah I'm ...
# 1  2020.08.24        댄스  Cos ah ahI’m in the stars tonightSo watch me b...
# 2  2020.10.02        댄스  영원한 밤창문 없는 방에 우릴 가둔 loveWhat can we say매번 아파도 ...
# 3  2020.07.20       발라드  언제부턴가 불쑥내 습관이 돼버린 너혹시나 이런 맘이어쩌면 부담일까널 주저했어언제부턴...
# 4  2020.10.20  R&B/Soul  똑같은 하루아무 표정 없는 날들지켜보는 것도 버거워여기까지인 것 같다고닿을 수 없단...
# 5  2020.08.12        댄스  마법 같았지 When we disco when we disco그래서 잊지를 못해 아...

# %%
#slicing으로 인덱스가 0부터 8까지,1줄씩 스킵
song_df.loc[0:8:2,:]
# Out:
#                                              곡명         가수  \
# 0                                DON'T TOUCH ME      환불원정대
# 2                                Lovesick Girls  BLACKPINK
# 4                                 놓아줘 (with 태연)      Crush
# 6                                  힘든 건 사랑이 아니다        임창정
# 8  Savage Love (Laxed - Siren Beat) (BTS Remix)  Jawsh 685
#
#                                              앨범         발매일        장르  \
# 0                                DON'T TOUCH ME  2020.10.10        댄스
# 2                                     THE ALBUM  2020.10.02        댄스
# 4                                      with HER  2020.10.20  R&B/Soul
# 6                                  힘든 건 사랑이 아니다  2020.10.19       발라드
# 8  Savage Love (Laxed - Siren Beat) [BTS Remix]  2020.10.02       POP
#
#                                                   가사
# 0  Trouble 이래 다 그래세 보인대 어쩔래난 멋 부리네 더 꾸미네yeah I'm ...
# 2  영원한 밤창문 없는 방에 우릴 가둔 loveWhat can we say매번 아파도 ...
# 4  똑같은 하루아무 표정 없는 날들지켜보는 것도 버거워여기까지인 것 같다고닿을 수 없단...
# 6  내가 널 떠났어야 했는데 왜 떠나야 하는지도 아는데 어떤 아무 말도 아무것도 줄 게...
# 8  Savage loveDid somebody did somebodyBreak your...

# %%
#여러개의 특정 행을 선택
#song_df.loc[[0,3,7,8]]
song_df.loc[[0,3,7,8],:]
# Out:
#                                              곡명         가수  \
# 0                                DON'T TOUCH ME      환불원정대
# 3                         취기를 빌려 (취향저격 그녀 X 산들)         산들
# 7                                        오래된 노래     스탠딩 에그
# 8  Savage Love (Laxed - Siren Beat) (BTS Remix)  Jawsh 685
#
#                                              앨범         발매일            장르  \
# 0                                DON'T TOUCH ME  2020.10.10            댄스
# 3                         취기를 빌려 (취향저격 그녀 X 산들)  2020.07.20           발라드
# 7                                        오래된 노래  2012.09.04  인디음악, 포크/블루스
# 8  Savage Love (Laxed - Siren Beat) [BTS Remix]  2020.10.02           POP
#
#                                                   가사
# 0  Trouble 이래 다 그래세 보인대 어쩔래난 멋 부리네 더 꾸미네yeah I'm ...
# 3  언제부턴가 불쑥내 습관이 돼버린 너혹시나 이런 맘이어쩌면 부담일까널 주저했어언제부턴...
# 7  오래 전에 함께 듣던 노래가발걸음을 다시 멈춰서게 해이 거리에서너를 느낄 수 있어널...
# 8  Savage loveDid somebody did somebodyBreak your...

# %%
#조건식을 만족하는 행과 모든열을 선택
condition = song_df['가수']=='방탄소년단'
song_df.loc[condition]
# Out:
#                                            곡명     가수  \
# 1                                    Dynamite  방탄소년단
# 27  작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)  방탄소년단
# 48                                         봄날  방탄소년단
# 53                                         ON  방탄소년단
# 92                       00:00 (Zero O’Clock)  방탄소년단
#
#                             앨범         발매일    장르  \
# 1   Dynamite (DayTime Version)  2020.08.24    댄스
# 27   MAP OF THE SOUL : PERSONA  2019.04.12    댄스
# 48        YOU NEVER WALK ALONE  2017.02.13  랩/힙합
# 53         MAP OF THE SOUL : 7  2020.02.21  랩/힙합
# 92         MAP OF THE SOUL : 7  2020.02.21  랩/힙합
#
#                                                    가사
# 1   Cos ah ahI’m in the stars tonightSo watch me b...
# 27  모든 게 궁금해How’s your dayOh tell me뭐가 널 행복하게 하는지O...
# 48  보고 싶다이렇게 말하니까 더 보고 싶다너희 사진을 보고 있어도보고 싶다너무 야속한 ...
# 53  I can't understand what people are sayin'어느 장단...
# 92  그런 날 있잖아이유 없이 슬픈 날몸은 무겁고나 빼곤 모두 다바쁘고 치열해 보이는 날...

# %%
condition = song_df['가수']=='BLACKPINK'
song_df.loc[condition]
# Out:
#                                곡명         가수                             앨범  \
# 2                  Lovesick Girls  BLACKPINK                      THE ALBUM
# 12              How You Like That  BLACKPINK              How You Like That
# 37  Ice Cream (with Selena Gomez)  BLACKPINK  Ice Cream (with Selena Gomez)
# 54                  Pretty Savage  BLACKPINK                      THE ALBUM
# 69  Bet You Wanna (Feat. Cardi B)  BLACKPINK                      THE ALBUM
#
#            발매일    장르                                                 가사
# 2   2020.10.02    댄스  영원한 밤창문 없는 방에 우릴 가둔 loveWhat can we say매번 아파도 ...
# 12  2020.06.26  랩/힙합  보란 듯이 무너졌어바닥을 뚫고 저 지하까지옷 끝자락 잡겠다고저 높이 두 손을 뻗어봐...
# 37  2020.08.28    댄스  Come a little closercause you looking thirstyI...
# 54  2020.10.02  랩/힙합  비슷한 것 같지 우린 뼛속까지 다름아이 창피하다가도 멍석 깔면 바름Born skin...
# 69  2020.10.02    댄스  BLACKPINKCardiTell me where you wanna goI’ll m...

# %%
#모든행과 특정 열을 1개 선택
song_df.loc[:,'가수'].head(2)
# Out:
# 0    환불원정대
# 1    방탄소년단
# Name: 가수, dtype: object

# %%
#모든행과 특정 열을 여러개 선택
song_df.loc[:,['가수','곡명','장르']].head(3)
# Out:
#           가수              곡명  장르
# 0      환불원정대  DON'T TOUCH ME  댄스
# 1      방탄소년단        Dynamite  댄스
# 2  BLACKPINK  Lovesick Girls  댄스

# %%
#장르가 댄스인 가수,곡명,장르,발매일을 선택하세요
song_df.loc[song_df['장르']=='댄스',['가수','곡명','장르','발매일']].reset_index(drop=True)
# Out:
#                      가수                                         곡명  장르  \
# 0                 환불원정대                             DON'T TOUCH ME  댄스
# 1                 방탄소년단                                   Dynamite  댄스
# 2             BLACKPINK                             Lovesick Girls  댄스
# 3                   박진영               When We Disco (Duet with 선미)  댄스
# 4           화사 (Hwa Sa)                                마리아 (Maria)  댄스
# 5     오마이걸 (OH MY GIRL)                                    Dolphin  댄스
# 6   싹쓰리 (유두래곤, 린다G, 비룡)                                  다시 여기 바닷가  댄스
# 7         마마무 (Mamamoo)                              딩가딩가 (Dingga)  댄스
# 8                 방탄소년단  작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)  댄스
# 9     오마이걸 (OH MY GIRL)                           살짝 설렜어 (Nonstop)  댄스
# 10              (여자)아이들                         덤디덤디 (DUMDi DUMDi)  댄스
# 11            BLACKPINK              Ice Cream (with Selena Gomez)  댄스
# 12            ITZY (있지)                                    Not Shy  댄스
# 13                   선미                       보라빛 밤 (pporappippam)  댄스
# 14                  아이유                            Into the I-LAND  댄스
# 15    Red Velvet (레드벨벳)                                     Psycho  댄스
# 16  싹쓰리 (유두래곤, 린다G, 비룡)                                  그 여름을 틀어줘  댄스
# 17            BLACKPINK              Bet You Wanna (Feat. Cardi B)  댄스
# 18                  이수현                                      ALIEN  댄스
# 19                   비룡                            신난다 (Feat. 마마무)  댄스
# 20         TWICE (트와이스)                                MORE & MORE  댄스
# 21        마마무 (Mamamoo)                                        HIP  댄스
# 22            유아 (오마이걸)                         숲의 아이 (Bon voyage)  댄스
# 23  싹쓰리 (유두래곤, 린다G, 비룡)                  여름 안에서 by 싹쓰리 (Feat. 황광희)  댄스
# 24                   청하                            PLAY (Feat. 창모)  댄스
#
#            발매일
# 0   2020.10.10
# 1   2020.08.24
# 2   2020.10.02
# 3   2020.08.12
# 4   2020.06.29
# 5   2020.04.27
# 6   2020.07.18
# 7   2020.10.20
# 8   2019.04.12
# 9   2020.04.27
# 10  2020.08.03
# 11  2020.08.28
# 12  2020.08.17
# 13  2020.06.29
# 14  2020.06.19
# 15  2019.12.23
# 16  2020.07.25
# 17  2020.10.02
# 18  2020.10.16
# 19  2020.08.01
# 20  2020.06.01
# 21  2019.11.14
# 22  2020.09.07
# 23  2020.07.11
# 24  2020.07.06

# %%
song_df.loc[song_df['장르']=='댄스',['가수','곡명','장르','발매일']]\
.sort_values(by='발매일',ascending=False).reset_index(drop=True)
# Out:
#                      가수                                         곡명  장르  \
# 0         마마무 (Mamamoo)                              딩가딩가 (Dingga)  댄스
# 1                   이수현                                      ALIEN  댄스
# 2                 환불원정대                             DON'T TOUCH ME  댄스
# 3             BLACKPINK                             Lovesick Girls  댄스
# 4             BLACKPINK              Bet You Wanna (Feat. Cardi B)  댄스
# 5             유아 (오마이걸)                         숲의 아이 (Bon voyage)  댄스
# 6             BLACKPINK              Ice Cream (with Selena Gomez)  댄스
# 7                 방탄소년단                                   Dynamite  댄스
# 8             ITZY (있지)                                    Not Shy  댄스
# 9                   박진영               When We Disco (Duet with 선미)  댄스
# 10              (여자)아이들                         덤디덤디 (DUMDi DUMDi)  댄스
# 11                   비룡                            신난다 (Feat. 마마무)  댄스
# 12  싹쓰리 (유두래곤, 린다G, 비룡)                                  그 여름을 틀어줘  댄스
# 13  싹쓰리 (유두래곤, 린다G, 비룡)                                  다시 여기 바닷가  댄스
# 14  싹쓰리 (유두래곤, 린다G, 비룡)                  여름 안에서 by 싹쓰리 (Feat. 황광희)  댄스
# 15                   청하                            PLAY (Feat. 창모)  댄스
# 16                   선미                       보라빛 밤 (pporappippam)  댄스
# 17          화사 (Hwa Sa)                                마리아 (Maria)  댄스
# 18                  아이유                            Into the I-LAND  댄스
# 19         TWICE (트와이스)                                MORE & MORE  댄스
# 20    오마이걸 (OH MY GIRL)                           살짝 설렜어 (Nonstop)  댄스
# 21    오마이걸 (OH MY GIRL)                                    Dolphin  댄스
# 22    Red Velvet (레드벨벳)                                     Psycho  댄스
# 23        마마무 (Mamamoo)                                        HIP  댄스
# 24                방탄소년단  작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)  댄스
#
#            발매일
# 0   2020.10.20
# 1   2020.10.16
# 2   2020.10.10
# 3   2020.10.02
# 4   2020.10.02
# 5   2020.09.07
# 6   2020.08.28
# 7   2020.08.24
# 8   2020.08.17
# 9   2020.08.12
# 10  2020.08.03
# 11  2020.08.01
# 12  2020.07.25
# 13  2020.07.18
# 14  2020.07.11
# 15  2020.07.06
# 16  2020.06.29
# 17  2020.06.29
# 18  2020.06.19
# 19  2020.06.01
# 20  2020.04.27
# 21  2020.04.27
# 22  2019.12.23
# 23  2019.11.14
# 24  2019.04.12

# %%
#모든 행과 Slicing을 사용하여 가수부터 발매일까지
song_df.loc[:,'가수':'발매일'].head(3)
# Out:
#           가수                          앨범         발매일
# 0      환불원정대              DON'T TOUCH ME  2020.10.10
# 1      방탄소년단  Dynamite (DayTime Version)  2020.08.24
# 2  BLACKPINK                   THE ALBUM  2020.10.02

# %%
### iloc[] 사용
#행의 인덱스가 0부터 5까지,열의 인덱스가 0:4
song_df.iloc[0:5,0:4]
# Out:
#                       곡명         가수                          앨범         발매일
# 0         DON'T TOUCH ME      환불원정대              DON'T TOUCH ME  2020.10.10
# 1               Dynamite      방탄소년단  Dynamite (DayTime Version)  2020.08.24
# 2         Lovesick Girls  BLACKPINK                   THE ALBUM  2020.10.02
# 3  취기를 빌려 (취향저격 그녀 X 산들)         산들       취기를 빌려 (취향저격 그녀 X 산들)  2020.07.20
# 4          놓아줘 (with 태연)      Crush                    with HER  2020.10.20

# %% [markdown]
# ### 100개의 song 정보가 들어있는 데아터프리임 객체를 DB에 저장
# * pymsql과 sqlalchemy를 사용한다.

# %%
# !pip show sqlalchemy
# Out:
# Name: SQLAlchemy
# Version: 1.3.18
# Summary: Database Abstraction Library
# Home-page: http://www.sqlalchemy.org
# Author: Mike Bayer
# Author-email: mike_mp@zzzcomputing.com
# License: MIT
# Location: c:\programdata\anaconda3\lib\site-packages
# Requires:
# Required-by:

# %%
import pymysql
#Db연결하는 역할.pymysql
import sqlalchemy
#내부적으로 실제 처리하는 역할.sqlalchemy

#mymysql과 sqlalchemy를 연동
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

#'mysql+mysqldb://scott:tiger@localhost/foo'
#Engine 객체 생성
engine = create_engine('mysql+mysqldb://python:python@localhost:3306/python_db',encoding='utf-8')
print(engine)
#Engine을 사용해서 DB에 연결
con = engine.connect()
print(con)

#DataFrame의 to_sql()함수로 dataFrame 객체를 Table로 저장
song_df.to_sql(name='songs',con=engine,if_exists='replace',index=False)
# Out:
# Engine(mysql+mysqldb://python:***@localhost:3306/python_db)
# <sqlalchemy.engine.base.Connection object at 0x0000022C2432E730>

# %%
#기존 DataFrame 객체의 복사본 생성
table_df = song_df.copy()
table_df.head()
# Out:
#                       곡명         가수                          앨범         발매일  \
# 0         DON'T TOUCH ME      환불원정대              DON'T TOUCH ME  2020.10.10
# 1               Dynamite      방탄소년단  Dynamite (DayTime Version)  2020.08.24
# 2         Lovesick Girls  BLACKPINK                   THE ALBUM  2020.10.02
# 3  취기를 빌려 (취향저격 그녀 X 산들)         산들       취기를 빌려 (취향저격 그녀 X 산들)  2020.07.20
# 4          놓아줘 (with 태연)      Crush                    with HER  2020.10.20
#
#          장르                                                 가사
# 0        댄스  Trouble 이래 다 그래세 보인대 어쩔래난 멋 부리네 더 꾸미네yeah I'm ...
# 1        댄스  Cos ah ahI’m in the stars tonightSo watch me b...
# 2        댄스  영원한 밤창문 없는 방에 우릴 가둔 loveWhat can we say매번 아파도 ...
# 3       발라드  언제부턴가 불쑥내 습관이 돼버린 너혹시나 이런 맘이어쩌면 부담일까널 주저했어언제부턴...
# 4  R&B/Soul  똑같은 하루아무 표정 없는 날들지켜보는 것도 버거워여기까지인 것 같다고닿을 수 없단...

# %%
table_df.columns = ['title','singer','album','relases_data','genre','lyric']
table_df.head(2)
# Out:
#             title singer                       album relases_data genre  \
# 0  DON'T TOUCH ME  환불원정대              DON'T TOUCH ME   2020.10.10    댄스
# 1        Dynamite  방탄소년단  Dynamite (DayTime Version)   2020.08.24    댄스
#
#                                                lyric
# 0  Trouble 이래 다 그래세 보인대 어쩔래난 멋 부리네 더 꾸미네yeah I'm ...
# 1  Cos ah ahI’m in the stars tonightSo watch me b...

# %%
#index가 1부터 시작되도록 변경
import numpy as np

table_df.index = np.arange(1,len(table_df)+1)
table_df.head(2)
# Out:
#             title singer                       album relases_data genre  \
# 1  DON'T TOUCH ME  환불원정대              DON'T TOUCH ME   2020.10.10    댄스
# 2        Dynamite  방탄소년단  Dynamite (DayTime Version)   2020.08.24    댄스
#
#                                                lyric
# 1  Trouble 이래 다 그래세 보인대 어쩔래난 멋 부리네 더 꾸미네yeah I'm ...
# 2  Cos ah ahI’m in the stars tonightSo watch me b...

# %% [markdown]
# ### 컬럼명과 DataType을 변경해서 Table로 저장하기

# %%
import pymysql
#Db연결하는 역할.pymysql
import sqlalchemy
#내부적으로 실제 처리하는 역할.sqlalchemy

#mymysql과 sqlalchemy를 연동
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

#'mysql+mysqldb://scott:tiger@localhost/foo'
#Engine 객체 생성
engine = create_engine('mysql+mysqldb://python:python@localhost:3306/python_db',encoding='utf-8')
print(engine)
#Engine을 사용해서 DB에 연결
con = engine.connect()
print(con)

#DataFrame의 to_sql()함수로 dataFrame 객체를 Table로 저장
table_df.to_sql(name='songs100',con=engine,if_exists='replace',index=True,index_label='id',\
              dtype = {
                    'id':sqlalchemy.types.INTEGER(),
                    'title':sqlalchemy.types.VARCHAR(100),
                    'singer':sqlalchemy.types.VARCHAR(100),
                    'album':sqlalchemy.types.VARCHAR(100),
                    'relases_data':sqlalchemy.DATE,
                    'genre':sqlalchemy.types.VARCHAR(100),
                    'lyric':sqlalchemy.types.VARCHAR(2500)
                      })
# Out:
# Engine(mysql+mysqldb://python:***@localhost:3306/python_db)
# <sqlalchemy.engine.base.Connection object at 0x0000022C276BB760>

# %% [markdown]
# ### table을 DataFrame 객체로 변환하기

# %%
import pymysql
#Db연결하는 역할.pymysql
import sqlalchemy
#내부적으로 실제 처리하는 역할.sqlalchemy

#mymysql과 sqlalchemy를 연동
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine

#'mysql+mysqldb://scott:tiger@localhost/foo'
#Engine 객체 생성
engine = create_engine('mysql+mysqldb://python:python@localhost:3306/python_db',encoding='utf-8')

print(engine)
#Engine을 사용해서 DB에 연결
con = engine.connect()
songs100_df = pd.read_sql_table('songs100',con)


#DB연결 종료
con.close()

songs100_df.head()
# Out:
# Engine(mysql+mysqldb://python:***@localhost:3306/python_db)
#    id                  title     singer                       album  \
# 0   1         DON'T TOUCH ME      환불원정대              DON'T TOUCH ME
# 1   2               Dynamite      방탄소년단  Dynamite (DayTime Version)
# 2   3         Lovesick Girls  BLACKPINK                   THE ALBUM
# 3   4  취기를 빌려 (취향저격 그녀 X 산들)         산들       취기를 빌려 (취향저격 그녀 X 산들)
# 4   5          놓아줘 (with 태연)      Crush                    with HER
#
#   relases_data     genre                                              lyric
# 0   2020-10-10        댄스  Trouble 이래 다 그래세 보인대 어쩔래난 멋 부리네 더 꾸미네yeah I'm ...
# 1   2020-08-24        댄스  Cos ah ahI’m in the stars tonightSo watch me b...
# 2   2020-10-02        댄스  영원한 밤창문 없는 방에 우릴 가둔 loveWhat can we say매번 아파도 ...
# 3   2020-07-20       발라드  언제부턴가 불쑥내 습관이 돼버린 너혹시나 이런 맘이어쩌면 부담일까널 주저했어언제부턴...
# 4   2020-10-20  R&B/Soul  똑같은 하루아무 표정 없는 날들지켜보는 것도 버거워여기까지인 것 같다고닿을 수 없단...

# %%
def search_album(keyword):
    sql = """select * from songs100 where album like %s;"""

    import pymysql
    #Db연결하는 역할.pymysql
    import sqlalchemy
    #내부적으로 실제 처리하는 역할.sqlalchemy

    #mymysql과 sqlalchemy를 연동
    pymysql.install_as_MySQLdb()
    from sqlalchemy import create_engine

    #'mysql+mysqldb://scott:tiger@localhost/foo'
    #Engine 객체 생성
    engine = create_engine('mysql+mysqldb://python:python@localhost:3306/python_db',encoding='utf-8')

    print(engine)
    #Engine을 사용해서 DB에 연결
    con = engine.connect()
    
    #query 실행한 결과를 DataFrame 객체로 변환하기
    album_df = pd.read_sql_query(sql, con=con, params=('%' + keyword + '%',))
    
    con.close()
    return album_df

# %%
result = search_album('OST')
result.head()
# Out:
# Engine(mysql+mysqldb://python:***@localhost:3306/python_db)
#    id                                  title    singer  \
# 0  17                                    아로하       조정석
# 1  31               흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야       장범준
# 2  33  모든 날, 모든 순간 (Every day, Every Moment)        폴킴
# 3  35                           사랑하게 될 줄 알았어       전미도
# 4  45                        Don't Start Now  Dua Lipa
#
#                      album relases_data        genre  \
# 0     슬기로운 의사생활 OST Part 3   2020-03-27   발라드, 국내드라마
# 1        멜로가 체질 OST Part 3   2019-08-23  록/메탈, 국내드라마
# 2  `키스 먼저 할까요?` OST Part.3   2018-03-20   발라드, 국내드라마
# 3    슬기로운 의사생활 OST Part 11   2020-05-22   발라드, 국내드라마
# 4         Future Nostalgia   2019-11-01          POP
#
#                                                lyric
# 0  어두운 불빛아래 촛불 하나와인 잔에 담긴 약속하나항상 너의 곁에서 널 지켜줄거야날 ...
# 1  흔들리는 꽃들 속에서네 샴푸향이 느껴진거야스쳐지나간건가 뒤돌아보지만그냥 사람들만 보...
# 2  네가 없이 웃을 수 있을까생각만 해도 눈물이나힘든 시간 날 지켜준 사람이제는 내가 ...
# 3  널 처음 사진으로 본 그날구십구년 일월 삼십일일그날 이후 지금 이 순간까지나 하나만...
# 4  If you don’t wanna see me Did a full 180 crazy...

# %%
def search_singer_and_title(singer_name,title_name):
    sql_2 = """select * from songs100 where singer like %s or title like %s;"""

    import pymysql
    #Db연결하는 역할.pymysql
    import sqlalchemy
    #내부적으로 실제 처리하는 역할.sqlalchemy

    #mymysql과 sqlalchemy를 연동
    pymysql.install_as_MySQLdb()
    from sqlalchemy import create_engine

    #'mysql+mysqldb://scott:tiger@localhost/foo'
    #Engine 객체 생성
    engine = create_engine('mysql+mysqldb://python:python@localhost:3306/python_db',encoding='utf-8')

    print(engine)
    #Engine을 사용해서 DB에 연결
    con = engine.connect()
    
    #query 실행한 결과를 DataFrame 객체로 변환하기
    album_df = pd.read_sql_query(sql_2, con=con, params=('%' + singer_name + '%','%' + title_name + '%'))
    
    con.close()
    return album_df

# %%
result2 = search_singer_and_title('아','아')
result2.head()
# Out:
# Engine(mysql+mysqldb://python:***@localhost:3306/python_db)
#    id                        title       singer                 album  \
# 0   5                놓아줘 (with 태연)        Crush              with HER
# 1   7                 힘든 건 사랑이 아니다          임창정          힘든 건 사랑이 아니다
# 2  12                  마리아 (Maria)  화사 (Hwa Sa)                 María
# 3  14  에잇(Prod.&Feat. SUGA of BTS)          아이유                    에잇
# 4  17                          아로하          조정석  슬기로운 의사생활 OST Part 3
#
#   relases_data       genre                                              lyric
# 0   2020-10-20    R&B/Soul  똑같은 하루아무 표정 없는 날들지켜보는 것도 버거워여기까지인 것 같다고닿을 수 없단...
# 1   2020-10-19         발라드  내가 널 떠났어야 했는데 왜 떠나야 하는지도 아는데 어떤 아무 말도 아무것도 줄 게...
# 2   2020-06-29          댄스  욕을 하도 먹어 체했어 하도서러워도 어쩌겠어 I do모두들 미워하느라 애썼네날 무너...
# 3   2020-05-06        록/메탈  So are you happy nowFinally happy now are you뭐...
# 4   2020-03-27  발라드, 국내드라마  어두운 불빛아래 촛불 하나와인 잔에 담긴 약속하나항상 너의 곁에서 널 지켜줄거야날 ...
